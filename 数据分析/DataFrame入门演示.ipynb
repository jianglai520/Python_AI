# %%
import pandas
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df1

df2 = pd.DataFrame({'A': [7, 8, 9], 'B': [10, 11, 12]})
df2

df3 = pd.concat([df1, df2])
df3

df4 = pd.DataFrame( [{"姓名":"小王", "语文":89, "数学":67, "英语":78},
    {"姓名":"小李", "语文":92, "数学":85, "英语":90},
    {"姓名":"小张", "语文":78, "数学":92, "英语":88},
    {"姓名":"小刘", "语文":95, "数学":78, "英语":82},
    {"姓名":"小陈", "语文":88, "数学":91, "英语":95},
    {"姓名":"小杨", "语文":76, "数学":83, "英语":79},
    {"姓名":"小赵", "语文":91, "数学":87, "英语":93},
    {"姓名":"小黄", "语文":84, "数学":76, "英语":85},
    {"姓名":"小周", "语文":87, "数学":94, "英语":88},
    {"姓名":"小吴", "语文":93, "数学":88, "英语":91}]
)
df4

df5 = pd.DataFrame([("小王", 89, 67, 78),("小李", 92, 85, 90),("小张", 78, 92, 88)], columns=["姓名", "语文", "数学", "英语"])
df5

df6 = pd.DataFrame([
    ["小王", 89, 67, 78],
    ["小李", 92, 85, 90],
    ["小张", 78, 92, 88]],
    columns=["姓名", "语文", "数学", "英语"],
    index = [1, 2, 3])   # 如何没有索引，则索引默认从0开始
df6
# dataframe 常见属性

df6.columns
df6.index   # 索引
df6.dtypes  # 数据类型
df6.values  # 数据
df6.shape # 数据维度(行数，列数)
df6.size   # 元素个数
df6.index.tolist()   # 索引
df6.columns.tolist() # 列
df6.info() #数据信息
# Out:
#    姓名  语文  数学  英语
# 1  小王  89  67  78
# 2  小李  92  85  90
# 3  小张  78  92  88
