# %%
import pandas as pd

s1 = pd.Series([1, 3, 5, 6, 8])
s1

s2 = pd.Series((10, 20, 30, 40), index = ['a', 'b', 'c', 'd'])
s2


s = pd.Series({'a': 23, 'b': 25, 'c': 30, 'd': 40})
s

# Series常见属性
s.index # Index(['a', 'b', 'c', 'd'], dtype='object')
s.values # array([23, 25, 30, 40])
s.shape  # (4,)
s.dtype # int64
s.values.tolist()  # [23, 25, 30, 40]
s.index.tolist()   # ['a', 'b', 'c', 'd']

df5 = pd.DataFrame([("小王", 89, 67, 78),("小李", 92, 85, 90),("小张", 78, 92, 88)], columns=["姓名", "语文", "数学", "英语"])
s4 = df5["姓名"]
# Out:
# ['a', 'b', 'c', 'd']
